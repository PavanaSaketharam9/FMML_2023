# %% [markdown]
# <a href="https://colab.research.google.com/github/PavanaSaketharam9/FMML_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 11:27:26--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   102MB/s    in 0.7s
#
# 2024-03-28 11:27:28 (102 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12728  1510.06895v1  The nuclear norm is widely used as a convex su...    cs
# 40989   1404.1144v1  Bioinformatics incorporates information regard...    cs
# 12478  1802.04852v2  Topological data analysis, such as persistent ...  stat
# 5739    1206.3241v1  We propose an approach for approximating the p...    cs
# 22515  1610.06665v1  Recent advances in Bayesian learning with larg...  stat
# ...             ...                                                ...   ...
# 47     1705.10929v1  Generative Adversarial Networks (GANs) have ga...    cs
# 7775   1803.03191v1  The rise of Online Social Networks (OSNs) has ...  stat
# 3500   1709.07359v1  Generative Adversarial Networks (GANs) produce...  stat
# 23956   1309.5004v1  In this paper, we present an algorithm for ide...    cs
# 39230  1501.05552v1  Linear mixture models are commonly used to rep...  stat
#
#                                                    title  year  \
# 12728  Nonconvex Nonsmooth Low-Rank Minimization via ...  2015
# 40989  AIS-MACA- Z: MACA based Clonal Classifier for ...  2014
# 12478  Persistence Codebooks for Topological Data Ana...  2018
# 5739   Approximating the Partition Function by Deleti...  2012
# 22515  On the Convergence of Stochastic Gradient MCMC...  2016
# ...                                                  ...   ...
# 47            Adversarial Generation of Natural Language  2017
# 7775   A Bayesian and Machine Learning approach to es...  2018
# 3500     Class-Splitting Generative Adversarial Networks  2017
# 23956  Blind Deconvolution via Maximum Kurtosis Adapt...  2013
# 39230  Estimating the Intrinsic Dimension of Hyperspe...  2015
#
#                                                 keywords
# 12728  [surrogate, compressive, applications, process...
# 40989  [bioinformatics, incorporates, information, re...
# 12478  [topological, persistent, beneficial, properti...
# 5739   [approximating, partition, computing, partitio...
# 22515  [witnessed, emergence, stochastic, algorithms,...
# ...                                                  ...
# 47     [generative, adversarial, attention, community...
# 7775   [insurmountable, advertisers, researchers, mon...
# 3500   [generative, adversarial, systematically, info...
# 23956  [algorithm, identifying, parametrically, descr...
# 39230  [represent, hyperspectral, combinations, endme...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12728    [surrogate, compressive, applications, process...
# 40989    [bioinformatics, incorporates, information, re...
# 12478    [topological, persistent, beneficial, properti...
# 5739     [approximating, partition, computing, partitio...
# 22515    [witnessed, emergence, stochastic, algorithms,...
#                                ...
# 5352     [inference, inherently, difficult, inference, ...
# 28151    [manufacturing, universal, fingerprint, finger...
# 30101    [extremely, convolutional, expression, recogni...
# 29525    [framework, recognition, handwritten, framewor...
# 14509    [portability, statistical, syntactic, knowledg...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8838 words.
# Out of those 4590 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0e45f559-2371-4668-a288-8823a1f1bf57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e45f559-2371-4668-a288-8823a1f1bf57")) {                    Plotly.newPlot(                        "0e45f559-2371-4668-a288-8823a1f1bf57",                        [{"x":["compressive","properties","synthesized","algorithm","extensive","monotonically","minimization","thresholding","processing","variables","approximate","stationary","surrogate","demonstrate","reweighted","decreases","functions","applications","suboptimal","nonconvex","iteratively","surrogates","experiments","algorithms","nonsmooth","objective","accessing","identification","attractor","techniques","strengthened","characteristics","addressed","efficiently","classifier","incorporates","regarding","sequences","boundaries","mechanisms","university","artificial","biological","bioinformatics","technique","components","information","presentation","clustering","outperform","difficult","efficient","persistence","approaches","persistent","encodings","representations","vectorial","beneficial","computationally","structure","topological","workflows","approximating","correcting","theoretically","empirical","simplified","computing","correction","complexity","approximation","degenerate","intuitive","framework","partition","practical","emergence","stochastic","posterior","advantages","asymptotic","witnessed","developed","integrators","iterations","splitting","integrator","counterparts","furthermore","theoretical","thermostat","symmetric","invariant","synthetic","hamiltonian","corresponding","decreasing","convergence","normalization","generalization","challenging","sequential","standardize","parallelize","normalizing","recurrent","recognition","potential","dependencies","expensive","particular","intermediate","significantly","normalized","performance","procedure","criterion","modelling","transitions","statistics","feedforward","representation","degradation","precision","multiplier","accelerator","classification","multiplications","applicability","interests","operations","significant","designing","platforms","architecture","promising","motivates","increasing","insignificant","arithmetic","different","computation","simplifies","inference","departing","naturally","guarantee","estimation","questions","introduced","specifically","reduction","determine","belonging","discriminator","distribution","distinguish","dynamically","equivalent","appropriate","generator","recovering","estimating","adversarial","likelihood","attempting","contrastive","distinguishability","corresponds","generative","procedures","negotiation","integrated","uncertainty","including","comprehensive","intelligent","manipulation","environment","technologies","knowledge","illustrate","assumptions","adversaries","underlying","computational","discussed","realistic","alternative","implementation","investigate","structures","introspection","collaborative","increased","restricted","repelling","limitations","deformable"],"y":[18,220,20,824,205,9,67,25,295,130,104,30,20,550,7,16,199,421,14,8,34,4,608,604,4,174,7,120,2,391,3,89,42,166,148,44,44,105,35,45,15,137,40,13,259,111,708,8,158,106,155,375,3,427,6,8,223,1,21,95,308,14,2,17,11,47,149,15,117,27,216,112,4,34,509,35,146,15,134,27,83,15,7,207,0,32,10,0,21,153,171,0,22,75,138,2,117,13,100,34,97,261,91,1,1,3,149,360,161,55,70,286,33,278,28,904,128,44,45,13,55,16,363,17,78,4,4,505,5,33,20,72,229,43,26,244,114,8,91,2,12,704,125,7,218,1,50,33,203,53,119,150,100,83,10,20,197,35,28,68,81,37,25,63,112,74,6,9,1,20,130,35,4,61,92,214,57,49,20,133,36,388,88,70,3,130,310,63,70,107,105,136,126,1,42,42,42,1,58,15],"type":"bar"},{"x":["compressive","properties","synthesized","algorithm","extensive"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4590,), (4590, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8158333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>Actionable</span> <span style=''>Email</span> <span style=''>Intent</span> <span style=''>Modeling</span> <span style=''>with</span> <span style=''>Reparametrized</span> <span style=''>RNNs</span> <br/><br/><span style=''>Emails</span> <span style=''>in</span> <span style=''>the</span> <span style=''>workplace</span> <span style=''>are</span> <span style=''>often</span> <span style=''>intentional</span> <span style=''>calls</span> <span style=''>to</span> <span style=''>action</span> <span style=''>for</span> <span style=''>its</span> <span style=''>recipients</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>annotate</span> <span style=''>these</span> <span style=''>emails</span> <span style=''>for</span> <span style=''>what</span> <span style=''>action</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recipient</span> <span style=''>will</span> <span style=''>take</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>of</span> <span style=''>action</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.7534246575342465);'>annotation</span> <span style=''>is</span> <span style=''>more</span> <span style=''>scalable</span> <span style=''>and</span> <span style=''>theory</span> <span style=''>agnostic</span> <span style=''>than</span> <span style='background-color:rgba(0, 255, 0, 0.33590733590733585);'>traditional</span> <span style=''>speech</span> <span style=''>act</span> <span style=''>based</span> <span style=''>email</span> <span style=''>intent</span> <span style='background-color:rgba(0, 255, 0, 0.7534246575342465);'>annotation</span> <span style=''>while</span> <span style=''>still</span> <span style=''>carrying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>semantic</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>pragmatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>action</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.7534246575342465);'>annotation</span> <span style=''>scheme</span> <span style=''>achieves</span> <span style=''>good</span> <span style=''>inter</span> <span style='background-color:rgba(0, 255, 0, 0.8);'>annotator</span> <span style='background-color:rgba(0, 255, 0, 0.5238095238095238);'>agreement</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>we</span> <span style=''>can</span> <span style=''>leverage</span> <span style=''>threaded</span> <span style=''>messages</span> <span style=''>from</span> <span style=''>other</span> <span style=''>domains</span> <span style=''>which</span> <span style=''>exhibit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparable</span> <span style=''>intents</span> <span style=''>in</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>conversation</span> <span style=''>with</span> <span style=''>domain</span> <span style=''>adaptive</span> <span style=''>RAINBOW</span> <span style=''>(Recurrently</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>AttentIve</span> <span style=''>Neural</span> <span style=''>Bag</span> <span style=''>Of</span> <span style=''>Words)</span> <span style=''>On</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>datasets</span> <span style='background-color:rgba(0, 255, 0, 0.38271604938271603);'>consisting</span> <span style=''>of</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>SARAH</span> <span style=''>A</span> <span style=''>Novel</span> <span style=''>Method</span> <span style=''>for</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>Problems</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Recursive</span> <span style=''>Gradient</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>StochAstic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Recursive</span> <span style=''>grAdient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algoritHm</span> <span style=''>(SARAH)</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>variant</span> <span style=''>SARAH</span> <span style=''>as</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>the</span> <span style=''>finite</span> <span style=''>sum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Different</span> <span style=''>from</span> <span style=''>the</span> <span style=''>vanilla</span> <span style=''>SGD</span> <span style=''>and</span> <span style=''>other</span> <span style=''>modern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>SVRG</span> <span style=''>S2GD</span> <span style=''>SAG</span> <span style=''>and</span> <span style=''>SAGA</span> <span style=''>SARAH</span> <span style=''>admits</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recursive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>updating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>to</span> <span style=''>SAGSAGA</span> <span style=''>SARAH</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style=''>a</span> <span style=''>storage</span> <span style=''>of</span> <span style=''>past</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>The</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>SARAH</span> <span style=''>is</span> <span style=''>proven</span> <span style=''>under</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convexity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>We</span> <span style=''>also</span> <span style=''>prove</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>(in</span> <span style=''>the</span> <span style=''>strongly</span> <span style=''>convex</span> <span style=''>case)</span> <span style=''>for</span> <span style=''>an</span> <span style=''>inner</span> <span style=''>loop</span> <span style=''>of</span> <span style=''>SARAH</span> <span style=''>the</span> <span style=''>property</span> <span style=''>that</span> <span style=''>SVRG</span> <span style=''>d ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Viral</span> <span style=''>Search</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <br/><br/><span style=''>The</span> <span style=''>article</span> <span style=''>after</span> <span style=''>a</span> <span style=''>brief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduction</span> <span style=''>on</span> <span style=''>genetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>functioning</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>kind</span> <span style=''>of</span> <span style=''>genetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style=''>Viral</span> <span style=''>Search</span> <span style=''>We</span> <span style=''>present</span> <span style=''>the</span> <span style=''>key</span> <span style=''>concepts</span> <span style=''>we</span> <span style=''>formally</span> <span style=''>derive</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>we</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.4014598540145986);'>numerical</span> <span style=''>tests</span> <span style=''>designed</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>and</span> <span style=''>limits</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style=''>post</span> <span style=''>picking</span> <span style=''>using</span> <span style=''>MAPPOS</span> <span style=''>improves</span> <span style=''>particle</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>from</span> <span style=''>Cryo</span> <span style=''>EM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>micrographs</span> <br/><br/><span style=''>Cryo</span> <span style=''>electron</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>microscopy</span> <span style=''>(cryo</span> <span style=''>EM)</span> <span style=''>studies</span> <span style=''>using</span> <span style=''>single</span> <span style=''>particle</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensively</span> <span style=''>used</span> <span style=''>to</span> <span style=''>reveal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>on</span> <span style=''>macromolecular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexes</span> <span style=''>Aiming</span> <span style=''>at</span> <span style=''>the</span> <span style=''>highest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achievable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>electron</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>microscopes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style=''>acquire</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thousands</span> <span style=''>of</span> <span style=''>high</span> <span style=''>quality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>micrographs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Particles</span> <span style=''>are</span> <span style=''>detected</span> <span style=''>on</span> <span style=''>and</span> <span style=''>boxed</span> <span style=''>out</span> <span style=''>from</span> <span style=''>each</span> <span style=''>micrograph</span> <span style=''>using</span> <span style=''>fully</span> <span style=''>or</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>However</span> <span style=''>the</span> <span style=''>obtained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particles</span> <span style=''>still</span> <span style=''>require</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>laborious</span> <span style=''>manual</span> <span style=''>post</span> <span style=''>picking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>which</span> <span style=''>is</span> <span style=''>one</span> <span style=''>major</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bottleneck</span> <span style=''>for</span> <span style=''>single</span> <span style=''>particle</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>MAPPOS</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>post</span> <span style=''>picking</span> <span style=''>strategy</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>boxed</spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13088816972312117)
# 	architecture (0.08773822366055375)
# 	processing (0.10607695073714492)
# 	segmentation (0.07371449119021935)
# 	information (0.2545846817691478)
# 	knowledge (0.13951815893563466)
# 	different (0.2531463502337289)
# 	detection (0.12837108953613807)
# 	convolutional (0.1312477526069759)
# 	recognition (0.12944983818770225)
#
# Some Statistics words are:
# 	convergence (0.1178801386825161)
# 	stochastic (0.13026250619118376)
# 	estimation (0.1644378405151065)
# 	theoretical (0.15502724120851907)
# 	statistical (0.15601783060921248)
# 	algorithm (0.4006934125804854)
# 	inference (0.1901931649331352)
# 	distribution (0.1827637444279346)
# 	dimensional (0.18771669143140168)
# 	regression (0.1827637444279346)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2a29ea5b-b04b-467c-b524-60eb634658e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a29ea5b-b04b-467c-b524-60eb634658e0")) {                    Plotly.newPlot(                        "2a29ea5b-b04b-467c-b524-60eb634658e0",                        [{"x":["compressive","properties","synthesized","algorithm","extensive","monotonically","minimization","thresholding","processing","variables","approximate","stationary","surrogate","demonstrate","reweighted","decreases","functions","applications","suboptimal","nonconvex","iteratively","surrogates","experiments","algorithms","nonsmooth","objective","accessing","identification","attractor","techniques","strengthened","characteristics","addressed","efficiently","classifier","incorporates","regarding","sequences","boundaries","mechanisms","university","artificial","biological","bioinformatics","technique","components","information","presentation","clustering","outperform","difficult","efficient","persistence","approaches","persistent","encodings","representations","vectorial","beneficial","computationally","structure","topological","workflows","approximating","correcting","theoretically","empirical","simplified","computing","correction","complexity","approximation","degenerate","intuitive","framework","partition","practical","emergence","stochastic","posterior","advantages","asymptotic","witnessed","developed","integrators","iterations","splitting","integrator","counterparts","furthermore","theoretical","thermostat","symmetric","invariant","synthetic","hamiltonian","corresponding","decreasing","convergence","normalization","generalization","challenging","sequential","standardize","parallelize","normalizing","recurrent","recognition","potential","dependencies","expensive","particular","intermediate","significantly","normalized","performance","procedure","criterion","modelling","transitions","statistics","feedforward","representation","degradation","precision","multiplier","accelerator","classification","multiplications","applicability","interests","operations","significant","designing","platforms","architecture","promising","motivates","increasing","insignificant","arithmetic","different","computation","simplifies","inference","departing","naturally","guarantee","estimation","questions","introduced","specifically","reduction","determine","belonging","discriminator","distribution","distinguish","dynamically","equivalent","appropriate","generator","recovering","estimating","adversarial","likelihood","attempting","contrastive","distinguishability","corresponds","generative","procedures","negotiation","integrated","uncertainty","including","comprehensive","intelligent","manipulation","environment","technologies","knowledge","illustrate","assumptions","adversaries","underlying","computational","discussed","realistic","alternative","implementation","investigate","structures","introspection","collaborative","increased","restricted","repelling","limitations","deformable","interplay","formulation","attracting","importance","important","fixations","robustness","supported","detection","additionally","integration","constitutes","connectivity","connected","ensembling","understood","geometric","performing","ensembles","polygonal","introduce","continuous","approximately","integrate","dimensional","translate","capturing","outperforms","indicates","leveraging","background","completion","experimental","relations","constrained","concentrate","factorization","transitivity","baselines","optimization","embedding","embeddings","unconstrained","annotated","reconsider","problematic","proliferation","annotating","represent","supporting","semantics","statistical","phenomena","prepositions","assumption","a ...

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	integrators
# 	integrator
# 	thermostat
# 	inferential
# 	layerwise
# 	prespecified
# 	gracefully
# 	eigenspaces
# 	radiographs
# 	radiological
# 	collapsed
# 	replicable
# 	sparsistent
# 	postulated
# 	precisionk
# 	lancaster
# 	parametrisation
# 	modulating
# 	parameterizes
# 	reparameterized
# Some words which never appear in Statistics papers:
# 	strengthened
# 	accelerator
# 	insignificant
# 	negotiation
# 	attracting
# 	fixations
# 	annotating
# 	prepositions
# 	backbones
# 	progressive
# 	satisfiability
# 	succession
# 	certified
# 	retinopathy
# 	hemorrhages
# 	adjudicated
# 	specialists
# 	undergoes
# 	tracklets
# 	localizing
